# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime

# %%
# reading the customer demographic table
cust_dem = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='CustomerDemographic', header=1)
cust_dem.sample()
# Out:
#      customer_id first_name last_name gender  \
# 441          442       Linc  Vedyasov   Male
#
#      past_3_years_bike_related_purchases        DOB job_title  \
# 441                                    2 2001-10-06       NaN
#
#     job_industry_category wealth_segment deceased_indicator  ... Unnamed: 16  \
# 441    Financial Services  Mass Customer                  N  ...         NaN
#
#     Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 441         NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 441          NaN          NaN          NaN          NaN
#
# [1 rows x 26 columns]

# %%
# getting table shape
cust_dem.shape
# Out:
# (4000, 26)

# %%
# getting list of all the columns
cust_dem.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
# removing 'Unnamed' columns
unnanmed_columns = [column for column in cust_dem.columns if 'Unnamed' in column]
cust_dem.drop(columns=unnanmed_columns, inplace=True)
cust_dem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
#  11  owns_car                             4000 non-null   object
#  12  tenure                               3913 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 406.4+ KB

# %%
# dropping meaningless columns
cust_dem.drop(columns='default', inplace=True)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Null Values and Incorrect values

# %%
# checking for Null values and percentage of Null values
for column in cust_dem.columns:
    if cust_dem[column].isna().sum() > 0:
        print({column: cust_dem[column].isna().sum() * 100 / len(cust_dem)})
# Out:
# {'last_name': 3.125}
# {'DOB': 2.175}
# {'job_title': 12.65}
# {'job_industry_category': 16.4}
# {'tenure': 2.175}

# %% [markdown]
# *High level of Null values is present in this table especially for 'job_title' and 'job_industry_category'*

# %%
# for analysis purpose we will use age instead of date of birth
cust_dem.DOB = pd.to_datetime(cust_dem.DOB)
cust_dem.insert(6, 'age', datetime.datetime.today().year - pd.to_datetime(cust_dem.DOB).dt.year)

# %%
# dropping DOB column
cust_dem.drop(columns='DOB', inplace=True)
cust_dem.sample(5)
# Out:
#       customer_id first_name   last_name  gender  \
# 3852         3853      Kerri  Marrington  Female
# 3406         3407     Marven       Ditts    Male
# 712           713      Adena   Northedge  Female
# 2964         2965      Lynna    Greenrod  Female
# 2301         2302    Loraine     Beamish  Female
#
#       past_3_years_bike_related_purchases   age                    job_title  \
# 3852                                   91  47.0      Accounting Assistant IV
# 3406                                   53  61.0              Cost Accountant
# 712                                    34  28.0         Help Desk Technician
# 2964                                   24  50.0                          NaN
# 2301                                   43  23.0  Mechanical Systems Engineer
#
#      job_industry_category  wealth_segment deceased_indicator owns_car  tenure
# 3852                   NaN   Mass Customer                  N      Yes    19.0
# 3406    Financial Services  High Net Worth                  N      Yes    19.0
# 712                    NaN   Mass Customer                  N      Yes     4.0
# 2964                   NaN  High Net Worth                  N       No     8.0
# 2301                Retail   Mass Customer                  N      Yes     4.0

# %%
# checkin for any unreal values
cust_dem.age.sort_values(ascending=False)
# Out:
# 33      179.0
# 719      91.0
# 1091     87.0
# 3409     82.0
# 2412     79.0
#         ...
# 3778      NaN
# 3882      NaN
# 3930      NaN
# 3934      NaN
# 3997      NaN
# Name: age, Length: 4000, dtype: float64

# %%
# handling 'age' column
cust_dem.age = cust_dem.age.replace(179, cust_dem.age.median())
cust_dem.age.fillna(cust_dem.age.median(), inplace=True)

# %%
print('Largest value for age: {}'.format(cust_dem.age.max()))
print('Number of Null values for age column: {}'.format(cust_dem.age.isna().sum()))
# Out:
# Largest value for age: 91.0
# Number of Null values for age column: 0

# %%
# Handling Null values

# No need to add anything to Last Name if a cutomer doesn't have one
cust_dem.last_name.fillna(' ', inplace=True)

# handling other null values
for feature in ['job_title', 'job_industry_category']:
    cust_dem[feature].fillna('Missing', inplace=True)

# handling tenure column
cust_dem.tenure.fillna(0, inplace=True)

# %%
# rechecking for Null values
cust_dem.isna().sum()
# Out:
# customer_id                            0
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# age                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# dtype: int64

# %%
cust_dem.sample(5)
# Out:
#       customer_id first_name last_name  gender  \
# 2732         2733   Jordanna     Skyme  Female
# 3213         3214   Cindelyn     Balas  Female
# 2997         2998   Quintana   Housley  Female
# 3210         3211      Betsy      Cosh  Female
# 3508         3509     Janine     Hesey  Female
#
#       past_3_years_bike_related_purchases   age  \
# 2732                                   89  37.0
# 3213                                    2  29.0
# 2997                                   34  22.0
# 3210                                   52  29.0
# 3508                                   85  44.0
#
#                           job_title job_industry_category  wealth_segment  \
# 2732  Analog Circuit Design manager         Manufacturing   Mass Customer
# 3213          Software Engineer III    Financial Services   Mass Customer
# 2997             Nurse Practicioner         Manufacturing  High Net Worth
# 3210       Automation Specialist II                Health  High Net Worth
# 3508                     Pharmacist                Health   Mass Customer
#
#      deceased_indicator owns_car  tenure
# 2732                  N      Yes    17.0
# 3213                  N      Yes     9.0
# 2997                  N      Yes     2.0
# 3210                  N      Yes     7.0
# 3508                  N      Yes    15.0

# %% [markdown]
# ### Categorical Features

# %%
# lsiting all the categorical features
categorical_features = [column for column in cust_dem.columns if cust_dem[column].dtype == 'O' and 
                        column not in ['first_name', 'last_name', 'default']]
categorical_features
# Out:
# ['gender',
#  'job_title',
#  'job_industry_category',
#  'wealth_segment',
#  'deceased_indicator',
#  'owns_car']

# %%
# getting unique values of all the categorical features
for feature in categorical_features:
    print(feature)
    print(cust_dem[feature].unique(),'\n')
# Out:
# gender
# ['F' 'Male' 'Female' 'U' 'Femal' 'M']
#
# job_title
# ['Executive Secretary' 'Administrative Officer' 'Recruiting Manager'
#  'Missing' 'Senior Editor' 'Media Manager I'
#  'Business Systems Development Analyst' 'Senior Quality Engineer'
#  'Nuclear Power Engineer' 'Developer I' 'Account Executive'
#  'Junior Executive' 'Media Manager IV' 'Sales Associate' 'Professor'
#  'Geological Engineer' 'Project Manager' 'Safety Technician I'
#  'Research Assistant I' 'Accounting Assistant III' 'Editor'
#  'Research Nurse' 'Safety Technician III' 'Staff Accountant III'
#  'Legal Assistant' 'Product Engineer' 'Information Systems Manager'
#  'VP Quality Control' 'Social Worker' 'Senior Cost Accountant'
#  'Assistant Media Planner' 'Payment Adjustment Coordinator' 'Food Chemist'
#  'Accountant III' 'Director of Sales' 'Senior Financial Analyst'
#  'Registered Nurse' 'Biostatistician II' 'Computer Systems Analyst II'
#  'Software Test Engineer II' 'Paralegal' 'VP Sales'
#  'Chief Design Engineer' 'Office Assistant III'
#  'Physical Therapy Assistant' 'Help Desk Operator' 'Web Developer II'
#  'Research Associate' 'Teacher' 'VP Product Management' 'Statistician II'
#  'Automation Specialist IV' 'Data Coordiator' 'Software Test Engineer III'
#  'Internal Auditor' 'Analyst Programmer' 'Occupational Therapist'
#  'Speech Pathologist' 'Quality Control Specialist' 'Civil Engineer'
#  'Software Engineer III' 'Community Outreach Specialist'
#  'Safety Technician IV' 'VP Accounting' 'General Manager'
#  'Nurse Practicioner' 'Automation Specialist II' 'Marketing Assistant'
#  'Marketing Manager' 'Staff Scientist' 'Assistant Professor'
#  'Budget/Accounting Analyst IV' 'Associate Professor' 'Graphic Designer'
#  'Administrative Assistant II' 'Compensation Analyst'
#  'Systems Administrator III' 'Financial Advisor' 'Chemical Engineer'
#  'Web Designer I' 'Senior Developer' 'Office Assistant II' 'Recruiter'
#  'Operator' 'Programmer Analyst III' 'Quality Engineer'
#  'Environmental Tech' 'Analog Circuit Design manager' 'Cost Accountant'
#  'Librarian' 'Structural Analysis Engineer' 'Pharmacist'
#  'Assistant Manager' 'Accountant I' 'Web Designer III' 'Geologist III'
#  'Software Test Engineer I' 'Structural Engineer' 'Safety Technician II'
#  'Web Developer III' 'Programmer Analyst II' 'Design Engineer'
#  'Statistician I' 'VP Marketing' 'Desktop Support Technician' 'Actuary'
#  'Database Administrator III' 'Electrical Engineer' 'Tax Accountant'
#  'Clinical Specialist' 'Database Administrator IV'
#  'Systems Administrator II' 'Account Coordinator' 'Programmer III'
#  'Administrative Assistant III' 'Nurse' 'Technical Writer'
#  'Staff Accountant II' 'Dental Hygienist' 'Sales Representative'
#  'Budget/Accounting Analyst III' 'Computer Systems Analyst IV'
#  'Geologist I' 'Financial Analyst' 'Accounting Assistant II'
#  'Senior Sales Associate' 'Database Administrator II' 'Engineer I'
#  'Budget/Accounting Analyst I' 'Developer IV' 'Database Administrator I'
#  'Environmental Specialist' 'Computer Systems Analyst I'
#  'Account Representative IV' 'Statistician IV' 'Human Resources Manager'
#  'GIS Technical Architect' 'Programmer IV' 'Accounting Assistant IV'
#  'Software Engineer IV' 'Programmer II' 'Engineer III'
#  'Software Consultant' 'Biostatistician IV' 'Help Desk Technician'
#  'Automation Specialist I' 'Developer III' 'Human Resources Assistant I'
#  'Geologist IV' 'Media Manager II' 'Statistician III' 'Engineer II'
#  'Health Coach II' 'Developer II' 'Systems Administrator I'
#  'Web Developer I' 'Software Engineer II' 'Accounting Assistant I'
#  'Research Assistant II' 'Programmer Analyst IV' 'Health Coach I'
#  'Accountant II' 'Automation Specialist III' 'Administrative Assistant I'
#  'Health Coach IV' 'Media Manager III' 'Account Representative III'
#  'Web Designer IV' 'Budget/Accounting Analyst II' 'Web Developer IV'
#  'Programmer I' 'Biostatistician III' 'Software Test Engineer IV'
#  'Research Assistant IV' 'Account Representative I' 'Accountant IV'
#  'Biostatistician I' 'Human Resources Assistant IV'
#  'Administrative Assistant IV' 'Office Assistant I'
#  'Human Resources Assistant II' 'Mechanical Systems Engineer'
#  'Engineer IV' 'Health Coach III' 'Office Assistant IV'
#  'Software Engineer I' 'Human Resources Assistant III'
#  'Staff Accountant I' 'Computer Systems Analyst III' 'Geologist II'
#  'Web Designer II' 'Staff Accountant IV' 'Account Representative II'
#  'Programmer Analyst I' 'Systems Administrator IV'
#  'Research Assistant III']
#
# job_industry_category
# ['Health' 'Financial Services' 'Property' 'IT' 'Missing' 'Retail'
#  'Argiculture' 'Manufacturing' 'Telecommunications' 'Entertainment']
#
# wealth_segment
# ['Mass Customer' 'Affluent Customer' 'High Net Worth']
#
# deceased_indicator
# ['N' 'Y']
#
# owns_car
# ['Yes' 'No']

# %% [markdown]
# *Gender categories can be changed from {'F', 'Male', 'Female', 'U', 'Femal' and 'M'} to {'Female', 'Male' and 'U}*

# %%
# cleaning the gender column
gender_map = {'F': 'Female', 'Femal': 'Female', 'Female': 'Female', 'Male': 'Male', 'M': 'Male', 'U': 'U'}
cust_dem.gender = cust_dem.gender.map(gender_map)

# %%
# checking for values in gender column
cust_dem.gender.unique()
# Out:
# array(['Female', 'Male', 'U'], dtype=object)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
cust_dem.head(5)
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot               Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases   age               job_title  \
# 0                                   93  69.0     Executive Secretary
# 1                                   81  42.0  Administrative Officer
# 2                                   61  68.0      Recruiting Manager
# 3                                   33  61.0                 Missing
# 4                                   56  45.0           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# 1    Financial Services      Mass Customer                  N      Yes    16.0
# 2              Property      Mass Customer                  N      Yes    15.0
# 3                    IT      Mass Customer                  N       No     7.0
# 4               Missing  Affluent Customer                  N      Yes     8.0

# %%
# saving file
cust_dem.to_excel(r'C:\Users\Mayank\Downloads\Customer Demographic.xlsx')

# %%
cust_dem.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot               Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases   age               job_title  \
# 0                                   93  69.0     Executive Secretary
# 1                                   81  42.0  Administrative Officer
# 2                                   61  68.0      Recruiting Manager
# 3                                   33  61.0                 Missing
# 4                                   56  45.0           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# 1    Financial Services      Mass Customer                  N      Yes    16.0
# 2              Property      Mass Customer                  N      Yes    15.0
# 3                    IT      Mass Customer                  N       No     7.0
# 4               Missing  Affluent Customer                  N      Yes     8.0
